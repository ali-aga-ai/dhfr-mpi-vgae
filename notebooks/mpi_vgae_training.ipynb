# %% [markdown]
# **Run the notebook in conda tf env** <br>
# **Conda activate tf**

# %%
from __future__ import division
from __future__ import print_function
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import scipy.sparse as sp
import seaborn as sns
# from node2vec import Node2Vec
from sklearn.metrics import roc_curve, auc, precision_recall_curve, f1_score
from pathlib import Path
import pickle
import glob

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')]

# %%
import scipy.sparse as sp
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
import time
import os


import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()
tf.set_random_seed(0)
# Build a TF v1 session that uses the GPU with memory growth
def make_gpu_session():
    cfg = tf.ConfigProto()
    cfg.gpu_options.allow_growth = True # gradual VRAM allocation
    cfg.allow_soft_placement = True # fall back to CPU if an op has no GPU kernel
    return tf.Session(config=cfg)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(0)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement = True

# %%
from vgae.optimizer import OptimizerAE, OptimizerVAE
from vgae.model import GCNModelVAE, GCNModelAE
from vgae.preprocessing import preprocess_graph, construct_feed_dict, sparse_to_tuple, mask_test_edges_seed

# %%
import scipy.sparse as sp
import scipy.stats as scs

# %% [markdown]
# ## Initialize VGAE Model

# %%
# Calculate ROC AUC
def get_roc_score_vgae(edges_pos, edges_neg, pos_weight, norm, emb=None):
    if emb is None:
        feed_dict.update({placeholders['dropout']: 0})
        emb = sess.run(model.z_mean, feed_dict=feed_dict)

    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    # Predict on test set of edges
    adj_rec = np.dot(emb, emb.T)
    preds_pos = []
    pos = []
    for e in edges_pos:
        preds_pos.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        pos.append(adj_orig[e[0], e[1]]) # actual value (1)

    preds_neg = []
    neg = []
    for e in edges_neg:
        preds_neg.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        neg.append(adj_orig[e[0], e[1]]) # actual value (0)

    preds_all = np.hstack([preds_pos, preds_neg])
    labels_all = np.hstack([np.ones(len(preds_pos)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    fpr, tpr, _ = roc_curve(labels_all, preds_all)
    precision, recall, _ = precision_recall_curve(labels_all, preds_all)
    pr_score = auc(recall, precision)
    ap_score = average_precision_score(labels_all, preds_all)
    
    # val_loss = norm * tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(labels=tf.constant(labels_all), logits=tf.constant(preds_all), pos_weight=pos_weight))
    # val_loss = tf.keras.backend.eval(val_loss)

    return roc_score, ap_score, fpr, tpr, pr_score, precision, recall

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
# saver = tf.train.Saver()
result = {}
for spcs in species[:1]:
    spcs_temp = {}
    for seed_num in seed_number:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pd.read_pickle(df_file_name)
        # node_feats = pickle.load(open(df_file_name, "rb" ))
        features = np.stack(node_feats['features'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        # features = np.random.rand(adj.shape[0],1024)
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        x = sp.lil_matrix(features)
        features_tuple = sparse_to_tuple(x)
        features_shape = features_tuple[2]
        # Get graph attributes (to feed into model)
        num_nodes = adj.shape[0] # number of nodes in adjacency matrix
        num_features = features_shape[1] # number of features (columsn of features matrix)
        features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = adj
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()
        # Normalize adjacency matrix
        adj_norm = preprocess_graph(adj_train)
        # Add in diagonals
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)
        cost_val = []
        acc_val = []
        val_roc_score = []
        train_loss_log = []
        val_loss_log = []
        # Define hyperparameters
        LEARNING_RATE = 0.005
        EPOCHS = 500
        HIDDEN1_DIM = 32
        HIDDEN2_DIM = 16
        DROPOUT = 0.1
        # Define placeholders
        placeholders = {
            'features': tf.sparse_placeholder(tf.float32),
            'adj': tf.sparse_placeholder(tf.float32),
            'adj_orig': tf.sparse_placeholder(tf.float32),
            'dropout': tf.placeholder_with_default(0., shape=())
        }

        # How much to weigh positive examples (true edges) in cost print_function
        # Want to weigh less-frequent classes higher, so as to prevent model output bias
        # pos_weight = (num. negative samples / (num. positive samples)
        pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

        # normalize (scale) average weighted cost
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        with tf.device('/gpu:0'):

            # Create VAE model
            model = GCNModelVAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

            opt = OptimizerVAE(preds=model.reconstructions,
                                    labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                                validate_indices=False), [-1]),
                                    model=model, num_nodes=num_nodes,
                                    pos_weight=pos_weight,
                                    norm=norm,
                                    learning_rate=LEARNING_RATE)

        # Initialize session
        with tf.device('/gpu:0'):
            sess = tf.Session(config=config)
        sess.run(tf.global_variables_initializer())

        # Train model
        for epoch in range(EPOCHS):
            t = time.time()
            # Construct feed dictionary
            feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
            feed_dict.update({placeholders['dropout']: DROPOUT})
            # Run single weight update
            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
            # train_loss_log.append(train_loss_epoch)

            # # Evaluate predictions
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
            val_roc_score.append(roc_curr)
            # val_loss_log.append(val_loss_epoch)
            
            if (epoch+1)%50 == 0:
            # Print results for this epoch
                print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                    "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                    "val_ap=", "{:.5f}".format(ap_curr),
                    "time=", "{:.5f}".format(time.time() - t))
                
            # if (epoch+1) % 100 == 0:
            #         saver.save(sess, './checkpoints/model', global_step=epoch+1)
        print("Optimization Finished!")
        # Print final results
        feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_vgae(test_edges, test_edges_false, pos_weight, norm)
        temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
        print('Test ROC score: ' + str(feature_roc_score))
        print('Test AP score: ' + str(feature_ap_score))
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./graph_model_vgae_features_final.pkl','wb'))
# Out:
# Homo sapiens 12345
# Creating GAE optimizer...
# Labels shape:  (?,)
# Preds shape:  (?,)
# CE+KL loss shape:  ()
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# /job:localhost/replica:0/task:0/device:GPU:2 -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# I0000 00:00:1758461618.762409 2230976 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1035 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1758461618.762861 2230976 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46866 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# I0000 00:00:1758461618.763126 2230976 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46866 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2025-09-21 19:03:38.925728: I tensorflow/core/common_runtime/placer.cc:162] PlaceholderWithDefault: (PlaceholderWithDefault): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925815: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925852: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925884: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925916: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925948: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/weights: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.925981: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/weights/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926011: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1_vars/weights/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926042: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/SparseToDense: (SparseToDense): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926074: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/SparseToDense: (SparseToDense): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926105: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926137: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926168: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926198: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926230: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926261: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926294: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/GreaterEqual: (GreaterEqual): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926327: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/dropout/SelectV2: (SelectV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926358: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/MatMul: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926388: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/MatMul_1: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926418: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926450: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926481: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926511: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926553: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926587: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/weights: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926594: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/weights/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926599: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2_vars/weights/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926605: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/SparseToDense_1: (SparseToDense): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926610: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926616: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926622: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926627: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926633: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926639: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926646: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/GreaterEqual: (GreaterEqual): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926651: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/dropout/SelectV2: (SelectV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926657: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/MatMul: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926662: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_2/MatMul_1: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926669: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926674: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926679: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926685: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926693: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/weights: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926698: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/weights/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926703: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3_vars/weights/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926709: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/SparseToDense_2: (SparseToDense): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926715: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926726: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926731: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926737: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926743: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926748: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926760: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/GreaterEqual: (GreaterEqual): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926766: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/dropout/SelectV2: (SelectV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926771: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/MatMul: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926777: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/graphconvolution_3/MatMul_1: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926783: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926789: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926795: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/random_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926801: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/Exp: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926807: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926812: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926818: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/transpose/Rank: (Rank): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926823: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/transpose/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926829: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/transpose/Range: (Range): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926836: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/transpose: (Transpose): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926842: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/MatMul: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926847: I tensorflow/core/common_runtime/placer.cc:162] gcnmodelvae/innerproductdecoder_1/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926853: I tensorflow/core/common_runtime/placer.cc:162] SparseToDense: (SparseToDense): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926859: I tensorflow/core/common_runtime/placer.cc:162] Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926866: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926871: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926877: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926884: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926889: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Abs: (Abs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926895: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926900: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Exp: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926905: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Log1p: (Log1p): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926911: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Neg_1: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926917: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926922: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926928: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss/mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926933: I tensorflow/core/common_runtime/placer.cc:162] logistic_loss: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926940: I tensorflow/core/common_runtime/placer.cc:162] Mean: (Mean): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926946: I tensorflow/core/common_runtime/placer.cc:162] mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926951: I tensorflow/core/common_runtime/placer.cc:162] mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926957: I tensorflow/core/common_runtime/placer.cc:162] add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926963: I tensorflow/core/common_runtime/placer.cc:162] Square: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926970: I tensorflow/core/common_runtime/placer.cc:162] sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926975: I tensorflow/core/common_runtime/placer.cc:162] Exp: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926981: I tensorflow/core/common_runtime/placer.cc:162] Square_1: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926987: I tensorflow/core/common_runtime/placer.cc:162] sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.926993: I tensorflow/core/common_runtime/placer.cc:162] Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927001: I tensorflow/core/common_runtime/placer.cc:162] Rank: (Rank): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927007: I tensorflow/core/common_runtime/placer.cc:162] range: (Range): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927013: I tensorflow/core/common_runtime/placer.cc:162] Mean_1: (Mean): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927019: I tensorflow/core/common_runtime/placer.cc:162] mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927024: I tensorflow/core/common_runtime/placer.cc:162] sub_2: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927031: I tensorflow/core/common_runtime/placer.cc:162] gradients/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927037: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_2_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927045: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927051: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927056: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927062: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927068: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927075: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927080: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927086: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927092: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_2_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927099: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_2_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927106: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927112: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927118: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927126: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927133: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927140: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927147: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927153: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927160: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927166: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927173: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927178: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927184: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927190: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927195: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Size: (Size): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927200: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927205: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927209: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927214: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/range: (Range): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927219: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/ones: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927224: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/DynamicStitch: (DynamicStitch): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927230: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927237: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/BroadcastTo: (BroadcastTo): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927243: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Shape_2: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927248: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Size_1: (Size): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927254: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927260: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/mod_1: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927266: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927272: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927278: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927284: I tensorflow/core/common_runtime/placer.cc:162] gradients/Mean_1_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927290: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927295: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927302: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927307: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927314: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927319: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927325: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927331: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927337: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927342: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927348: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927354: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/Size: (Size): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927359: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927364: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927369: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/range: (Range): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927374: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/ones: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927379: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/DynamicStitch: (DynamicStitch): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927385: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927391: I tensorflow/core/common_runtime/placer.cc:162] gradients/Sum_grad/BroadcastTo: (BroadcastTo): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927396: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927402: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927408: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927414: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927421: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927426: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927433: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927439: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927445: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927451: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927456: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927462: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_1_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927467: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927473: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927479: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927485: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927491: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927496: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927502: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927508: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927514: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927520: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927525: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927532: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/mul_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927537: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927543: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927550: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927555: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927561: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927567: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927573: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927579: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927585: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927590: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927595: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_1_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927601: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927607: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927612: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927618: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927624: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927630: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927635: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927641: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927646: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927653: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/add_1_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927659: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927666: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927671: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927678: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927684: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927690: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927696: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927702: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927709: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927714: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927719: I tensorflow/core/common_runtime/placer.cc:162] gradients/sub_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927725: I tensorflow/core/common_runtime/placer.cc:162] gradients/Square_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927731: I tensorflow/core/common_runtime/placer.cc:162] gradients/Square_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927737: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Log1p_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927743: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Log1p_grad/Reciprocal: (Reciprocal): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927748: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Log1p_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927755: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Relu_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927761: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927767: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927773: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927779: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927785: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927791: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927797: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927802: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927808: I tensorflow/core/common_runtime/placer.cc:162] gradients/add_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927813: I tensorflow/core/common_runtime/placer.cc:162] gradients/Square_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927820: I tensorflow/core/common_runtime/placer.cc:162] gradients/Square_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927826: I tensorflow/core/common_runtime/placer.cc:162] gradients/Exp_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927832: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Exp_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927838: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Neg_1_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927844: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927849: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927856: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927862: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927868: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927873: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927879: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927886: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927892: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927897: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927902: I tensorflow/core/common_runtime/placer.cc:162] gradients/mul_1_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927908: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Neg_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927914: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Abs_grad/Sign: (Sign): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927920: I tensorflow/core/common_runtime/placer.cc:162] gradients/logistic_loss/Abs_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927926: I tensorflow/core/common_runtime/placer.cc:162] gradients/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927933: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/Reshape_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927939: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/Reshape_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927945: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/MatMul: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927951: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/MatMul_1: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927958: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927964: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927970: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927977: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927985: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927991: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.927997: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928003: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928009: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928015: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928020: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928026: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/MatMul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928032: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/transpose_grad/InvertPermutation: (InvertPermutation): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928037: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/innerproductdecoder_1/transpose_grad/transpose: (Transpose): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928042: I tensorflow/core/common_runtime/placer.cc:162] gradients/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928048: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/add_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928054: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/add_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928060: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/add_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.928065: I tensorflow/core/common_runtime/placer.cc:162] gradients/gcnmodelvae/add_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# 2025-09-21 19:03:38.977508: I tensorflow/core/common_runtime/placer.cc:162] Adam_3/beta1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977514: I tensorflow/core/common_runtime/placer.cc:162] Adam_3/beta2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977519: I tensorflow/core/common_runtime/placer.cc:162] Adam_3/epsilon: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977527: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977532: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/grad_ys_0/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977539: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_9_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977545: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_9_grad/Size: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977551: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_9_grad/GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977557: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_9_grad/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977562: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_10_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977567: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_10_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977572: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_10_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977578: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_10_grad/GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977584: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Mean_10_grad/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977590: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Sum_3_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977595: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Sum_3_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977600: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Sum_3_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977605: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Sum_3_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977611: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Square_7_grad/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977618: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/logistic_loss_3/Log1p_grad/add/x: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977624: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/add_3_grad/Shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977630: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/Square_6_grad/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977636: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/mul_10_grad/Shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977643: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977648: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977654: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977660: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977665: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977671: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/innerproductdecoder_4/MatMul_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977677: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977683: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977688: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977694: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977700: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977705: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_1_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977712: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/mul_grad/Shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977719: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977725: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977732: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977737: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977744: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977750: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977756: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/MatMul_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977762: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/dropout/SelectV2_grad/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977768: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/dropout/SelectV2_grad/Shape_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977774: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977780: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977786: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977791: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977797: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977802: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_1_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977809: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_11/dropout/RealDiv_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977815: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977822: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977827: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977833: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977840: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977846: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977852: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/MatMul_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977859: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/dropout/SelectV2_grad/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977865: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/dropout/SelectV2_grad/Shape_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977871: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_12/dropout/RealDiv_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977877: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977883: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977889: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977895: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977901: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977907: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_1_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977913: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977919: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977926: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977932: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977938: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977944: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977949: I tensorflow/core/common_runtime/placer.cc:162] gradients_7/gcnmodelvae_3/graphconvolution_10/MatMul_grad/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.977956: I tensorflow/core/common_runtime/placer.cc:162] GreaterEqual_3/y: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-09-21 19:03:38.994189: I tensorflow/core/common_runtime/placer.cc:162] Const_7: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 94
#      92 avg_cost = outs[1]
#      93 avg_accuracy = outs[2]
# ---> 94 roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
#      95 # train_loss_log.append(train_loss_epoch)
#      96
#      97 # # Evaluate predictions
#      98 roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
#
# Cell In[23], line 21, in get_roc_score_vgae(edges_pos, edges_neg, pos_weight, norm, emb)
#      19 neg = []
#      20 for e in edges_neg:
# ---> 21     preds_neg.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
#      22     neg.append(adj_orig[e[0], e[1]]) # actual value (0)
#      24 preds_all = np.hstack([preds_pos, preds_neg])
#
# KeyboardInterrupt:
